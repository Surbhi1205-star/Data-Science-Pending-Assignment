# %%
# Install mlxtend if you haven't already
#!pip install mlxtend

import pandas as pd
import numpy as np
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules
dataset = pd.read_excel("Online retail.xlsx")
dataset
# Out:
# C:\Users\Surbhi\anaconda3\Lib\site-packages\openpyxl\packaging\core.py:99: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   now = datetime.datetime.utcnow()
# C:\Users\Surbhi\anaconda3\Lib\site-packages\openpyxl\packaging\core.py:99: DeprecationWarning: datetime.datetime.utcnow() is deprecated and scheduled for removal in a future version. Use timezone-aware objects to represent datetimes in UTC: datetime.datetime.now(datetime.UTC).
#   now = datetime.datetime.utcnow()
#               item1              item2        item3             item4  \
# 0            shrimp            almonds      avocado    vegetables mix
# 1           burgers          meatballs         eggs               NaN
# 2           chutney                NaN          NaN               NaN
# 3            turkey            avocado          NaN               NaN
# ...

# %%
dataset.columns
# Out:
# Index(['item1', 'item2', 'item3', 'item4', 'item5', 'item6', 'item7', 'item8',
#        'item9', 'item10', 'item11', 'item12', 'item13', 'item14', 'item15',
#        'item16', 'item17', 'item18', 'item19', 'item20'],
#       dtype='object')

# %%
dataset.columns

# %%
dataset["item1"][4]
# Out:
# 'mineral water'

# %%
type(dataset["item1"][4])
# Out:
# str

# %%
dataset.shape
# Out:
# (7501, 20)

# %%
market = []
for i in range (0,dataset.shape[0]):
    cus = []
    for j in dataset.columns:
# print(df[j][i])
        if type(dataset[j][i])==str:
            cus.append(dataset[j][i])
    market.append(cus)

# %%
market
# Out:
# [['shrimp',
#   'almonds',
#   'avocado',
#   'vegetables mix',
#   'green grapes',
#   'whole weat flour',
#   'yams',
#   'cottage cheese',
#   'energy drink',
#   'tomato juice',
#   'low fat yogurt',
#   'green tea',
#   'honey',
#   'salad',
#   'mineral water',
#   'salmon',
#   'antioxydant juice',
#   'frozen smoothie',
#   'spinach',
#   'olive oil'],
#  ['burgers', 'meatballs', 'eggs'],
#  ['chutney'],
#  ['turkey', 'avocado'],
#  ['mineral water', 'milk', 'energy bar', 'whole wheat rice', 'green tea'],
#  ['low fat yogurt'],
#  ['whole wheat pasta', 'french fries'],
#  ['soup', 'light cream', 'shallot'],
#  ['frozen vegetables', 'spaghetti', 'green tea'],
#  ['french fries'],
#  ['eggs', 'pet food'],
#  ['cookies'],
#  ['turkey', 'burgers', 'mineral water', 'eggs', 'cooking oil'],
#  ['spaghetti', 'champagne', 'cookies'],
#  ['mineral water', 'salmon'],
#  ['mineral water'],
#  ['shrimp',
#   'chocolate',
#   'chicken',
#   'honey',
#   'oil',
#   'cooking oil',
# ...

# %%
dataset["item1"][7500]
# Out:
# 'eggs'

# %%
import collections

# %%
# to ci=onvert market in single list

# %%
l = []
for i in market:
    for j in i :
       l.append(j)

# %%
p = collections.Counter(l)

# %%
p.values()
# Out:
# dict_values([536, 153, 250, 193, 68, 70, 86, 239, 200, 228, 574, 991, 356, 37, 1788, 319, 67, 475, 53, 494, 654, 157, 1348, 31, 469, 972, 203, 439, 221, 1282, 379, 117, 58, 715, 1306, 49, 603, 383, 351, 1230, 450, 173, 167, 513, 107, 90, 139, 211, 118, 199, 37, 141, 47, 203, 86, 713, 393, 124, 61, 149, 323, 737, 595, 371, 106, 82, 160, 58, 45, 608, 243, 253, 193, 63, 65, 181, 204, 101, 47, 79, 36, 205, 131, 226, 35, 169, 69, 29, 81, 46, 71, 115, 143, 73, 46, 31, 78, 3, 32, 42, 99, 69, 65, 102, 52, 33, 68, 39, 34, 34, 90, 36, 65, 33, 14, 44, 33, 1, 7, 5])

# %%
p.keys()
# Out:
# dict_keys(['shrimp', 'almonds', 'avocado', 'vegetables mix', 'green grapes', 'whole weat flour', 'yams', 'cottage cheese', 'energy drink', 'tomato juice', 'low fat yogurt', 'green tea', 'honey', 'salad', 'mineral water', 'salmon', 'antioxydant juice', 'frozen smoothie', 'spinach', 'olive oil', 'burgers', 'meatballs', 'eggs', 'chutney', 'turkey', 'milk', 'energy bar', 'whole wheat rice', 'whole wheat pasta', 'french fries', 'soup', 'light cream', 'shallot', 'frozen vegetables', 'spaghetti', 'pet food', 'cookies', 'cooking oil', 'champagne', 'chocolate', 'chicken', 'oil', 'fresh tuna', 'tomatoes', 'black tea', 'extra dark chocolate', 'protein bar', 'red wine', 'pasta', 'pepper', 'shampoo', 'rice', 'sparkling water', 'ham', 'body spray', 'pancakes', 'grated cheese', 'white wine', 'toothpaste', 'parmesan cheese', 'fresh bread', 'ground beef', 'escalope', 'herb & pepper', 'tomato sauce', 'magazines', 'strawberries', 'strong cheese', 'pickles', 'cake', 'hot dogs', 'brownies', 'cereals', 'c
# ...

# %%
d = {"item Name":p.keys(),"values": p.values()}

# %%
pd.DataFrame(d).sort_values(by = ["values"],ascending=False)
# Out:
#          item Name  values
# 14   mineral water    1788
# 22            eggs    1348
# 34       spaghetti    1306
# 29    french fries    1282
# 39       chocolate    1230
# ..             ...     ...
# 114        bramble      14
# 118          cream       7
# 119        napkins       5
# 97     water spray       3
# 117      asparagus       1
#
# [120 rows x 2 columns]

# %%
dataset.isnull().sum()
# Out:
# item1        0
# item2     1754
# item3     3112
# item4     4156
# item5     4972
# item6     5637
# item7     6132
# item8     6520
# item9     6847
# item10    7106
# item11    7245
# item12    7347
# item13    7414
# item14    7454
# item15    7476
# item16    7493
# item17    7497
# item18    7497
# item19    7498
# item20    7500
# dtype: int64

# %%
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.preprocessing import TransactionEncoder

# Convert transactions to a format suitable for mlxtend
tr = TransactionEncoder()
tr.fit(market)
tr.transform(market)
# Out:
# array([[False,  True,  True, ...,  True, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False,  True, False]])

# %%
df = pd.DataFrame(tr.transform(market), columns=tr.columns_)
df
# Out:
#        asparagus  almonds  antioxydant juice  asparagus  avocado  babies food  \
# 0          False     True               True      False     True        False
# 1          False    False              False      False    False        False
# 2          False    False              False      False    False        False
# 3          False    False              False      False     True        False
# 4          False    False              False      False    False        False
# ...          ...      ...                ...        ...      ...          ...
# 7496       False    False              False      False    False        False
# 7497       False    False              False      False    False        False
# 7498       False    False              False      False    False        False
# 7499       False    False              False      False    False        False
# 7500       False    False              False      False    False        False
#
# ...

# %%
from mlxtend.frequent_patterns import apriori

# %%
apriori(df,min_support=0.7,use_colnames=True,max_len=3)
# Out:
# Empty DataFrame
# Columns: [support, itemsets]
# Index: []

# %%
# Apply Apriori algorithm to find frequent itemsets
frequent_itemsets = apriori(df, min_support=0.02, use_colnames=True)

frequent_itemsets
# Out:
#       support                           itemsets
# 0    0.020397                          (almonds)
# 1    0.033329                          (avocado)
# 2    0.033729                         (brownies)
# 3    0.087188                          (burgers)
# 4    0.030129                           (butter)
# ..        ...                                ...
# 98   0.020131  (mineral water, whole wheat rice)
# 99   0.022930             (spaghetti, olive oil)
# 100  0.025197              (pancakes, spaghetti)
# 101  0.021197                (spaghetti, shrimp)
# 102  0.020931              (spaghetti, tomatoes)
#
# [103 rows x 2 columns]

# %%
# Generate association rules with confidence and lift
rules = association_rules(frequent_itemsets, metric="lift", min_threshold=1.0,num_itemsets=4)
rules
# Out:
#        antecedents      consequents  antecedent support  consequent support  \
# 0        (burgers)           (eggs)            0.087188            0.179709
# 1           (eggs)        (burgers)            0.179709            0.087188
# 2   (french fries)        (burgers)            0.170911            0.087188
# 3        (burgers)   (french fries)            0.087188            0.170911
# 4        (burgers)  (mineral water)            0.087188            0.238368
# ..             ...              ...                 ...                 ...
# 89     (spaghetti)       (pancakes)            0.174110            0.095054
# 90     (spaghetti)         (shrimp)            0.174110            0.071457
# 91        (shrimp)      (spaghetti)            0.071457            0.174110
# 92     (spaghetti)       (tomatoes)            0.174110            0.068391
# 93      (tomatoes)      (spaghetti)            0.068391            0.174110
#
# ...

# %% [markdown]
# 1.What is lift and why is it important in Association rules?
#
# In data mining and association rule learning, lift is a measure of the performance of a targeting model (association rule)
# at predicting or classifying cases as having an enhanced response (with respect to the population as a whole),
# measured against a random choice targeting model.
#
#
# 2.What is support and Confidence. How do you calculate them?
#
# In general, the support of an itemset can be calculated using the following formula:
# where X is the itemset for which you are calculating the support. In data mining,
# confidence is a measure of the reliability or support for a given association rule.
#
#
# 3.What are some limitations or challenges of Association rules mining?
# Limitations and challenges of Association Rules Mining include12:
#
#     Scalability: Dealing with large datasets can be computationally expensive.
#     Redundancy: Generated rules may contain redundant information.
#     Interpretability: Ensuring meaningful and interpretable results requires careful parameter tuning.
